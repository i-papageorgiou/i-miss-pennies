# %%
import random

# %%
my_dict = {'A': 1, 'B':2, 'C':3}

# %%
dict_items = list(my_dict.items())

# %%
random.shuffle(dict_items)

# %%
shuffled_dict = dict(dict_items)

# %%
shuffled_dict
# Out:
# {'C': 3, 'B': 2, 'A': 1}
